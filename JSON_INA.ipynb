# %% [markdown]
# # ![imagen.png](attachment:imagen.png)

# %% [markdown]
# PAGINA: https://alerta.ina.gob.ar/pub/mapa Se va a tratar de vincular los datos a la estacion Libertad.

# %% [markdown]
# Si bien, cuando se abre la estacion los "DATOS" son los referidos a la misma, en este caso la estacion Libertad, en el sector de TABLA, figuran todas las estaciones - en el sector de servicios web se encuentra el URL, que consultamos a continuacion.

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
import json
import requests

# %%
if __name__=='__main__':
    url='https://alerta.ina.gob.ar/pub/datos/datos&seriesId=10&timeStart=2020-04-21T00:00:00.000Z&timeEnd=2020-04-22T00:00:00.000Z'
    arg ={'id'}
    resp01 = requests.get(url, params = arg)

print(resp01.content)
# Out:
# b'{"requestHeader":{"request":"datos","seriesId":"10","timeStart":"2020-04-21T00:00:00.000Z","timeEnd":"2020-04-22T00:00:00.000Z"},"responseHeader":{"timeStart":"20200420T210000","request":"datos","sitecode":10,"seriesid":10,"seriesId":"10","timeEnd":"20200421T210000","creationTime":"2020-04-22T19:26:40-03:00","queryUrl":"request=datos&seriesId=10&timeStart=2020-04-21T00:00:00.000Z&timeEnd=2020-04-22T00:00:00.000Z","seriesmetadata":{"var_abrev":"altura","unit_abrev":"m","unitId":11,"seriesId":10,"procId":1,"proc_abrev":"medicion","varId":2},"responseTimestamp":"2020-04-22T19:26:40","sitemetadata":{"redId":10,"siteCode":10,"red_name":"escalas Prefectura Nacional","geom":{"coordinates":[-54.621134,-25.916679],"type":"Point"},"estacion_abrev":null}},"data":[{"obs_id":12483644980,"timestart":"2020-04-21T00:00:00","timeend":"2020-04-21T00:00:00","valor":5.3,"timeupdate":"2020-04-21T07:08:20.383122"}]}'

# %% [markdown]
# _**Se realizara el mismo request pero con los argumentos correspondientes**_

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# **https://alerta.ina.gob.ar/pub/datos/datos&seriesId=10&timeStart=2020-04-21T00:00:00.000Z&timeEnd=2020-04-22T00:00:00.000Z**

# %%
if __name__=='__main__':
    url = 'https://alerta.ina.gob.ar/pub/datos'
    args = {
        'request' :'datos',
        'seriesId':'10',
        'timeStart':'2020-04-21T00:00:00.000Z',
        'timeEnd':'2020-04-22T00:00:00.000Z',
    }

    
    resp_01 = requests.get(url, args)

print(resp_01.content)
# Out:
# b'{"requestHeader":{"request":"capabilities"},"responseHeader":{"request":"capabilities","queryUrl":"request=capabilities","responseTimestamp":"2020-04-22T19:40:36","creationTime":"2020-04-22T19:40:36-03:00"},"data":[{"description":"Este documento","name":"capabilities","location":"/pub/datos/capabilities"},{"description":"Listado de redes de medici\xc3\xb3n disponibles","name":"redes","location":"/pub/datos/redes","validParameters":["exists","desc","format"],"example":"/pub/datos/redes&format=json"},{"validParameters":["redId","siteCode","match","type","distrito","pais","norte","sur","este","oeste","exists","desc","format"],"description":"Listado de estaciones de medici\xc3\xb3n disponibles","name":"estaciones","location":"/pub/datos/estaciones","example":"/pub/datos/estaciones&format=geojson"},{"validParameters":["siteCode","exists","match","desc","format"],"description":"Listado de cuencas o \xc3\xa1reas de inter\xc3\xa9s hidrol\xc3\xb3gico disponibles","location":"/pub/datos/cuen
# ...

# %% [markdown]
# {"request":"datos","seriesId":"10","timeStart":"2020-04-21T00:00:00.000Z","timeEnd":"2020-04-22T00:00:00.000Z"}

# %% [markdown]
# ![imagen.png](attachment:imagen.png)
